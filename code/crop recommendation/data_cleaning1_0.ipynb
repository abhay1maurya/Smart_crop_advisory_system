# %%
import pandas as pd

# %%
data= pd.read_csv("crop_data.csv")

# %%
data.head(5)
# Out:
#       N     P     K  temperature   humidity        ph    rainfall label
# 0  90.0  42.0  43.0    20.879744  82.002744  6.502985  202.935536  rice
# 1  85.0  58.0  41.0    21.770462  80.319644  7.038096  226.655537  rice
# 2  60.0  55.0  44.0    23.004459  82.320763  7.840207  263.964248  rice
# 3  74.0  35.0  40.0    26.491096  80.158363  6.980401  242.864034  rice
# 4  78.0  42.0  42.0    20.130175  81.604873  7.628473  262.717340  rice

# %%
data.describe()
# Out:
#                   N             P             K   temperature      humidity  \
# count  55775.000000  55775.000000  55775.000000  55775.000000  55775.000000
# mean      62.925272     47.488457     49.834265     23.872623     69.480708
# std       38.026048     22.506827     37.532724      9.100788     20.787847
# min        0.000000      0.000000      0.000000     -9.770358      0.241239
# 25%       31.000000     35.481222     20.000000     21.084541     62.017848
# 50%       60.000000     40.720676     40.000000     25.600000     77.556610
# 75%       82.000000     60.000000     65.000000     28.994545     83.626444
# max      194.670114    150.000000    500.000000     47.861322    104.980970
#
#                  ph      rainfall
# count  55775.000000  55775.000000
# mean       6.287279    523.213010
# std        1.895346    549.928693
# min        0.005469      0.000000
# 25%        5.440000     98.940000
# 50%        6.081173    295.924880
# 75%        6.756027    818.817284
# max       13.989251   3322.060000

# %%
duplicate_columns = ['N','P','K','temperature','humidity','ph','rainfall','label']

# %%
data.duplicated(subset=duplicate_columns, keep='first').sum()
# Out:
# np.int64(24714)

# %%
df_cleaned = data.drop_duplicates()

# %%
df_cleaned.duplicated(subset=duplicate_columns, keep='first').sum()
# Out:
# np.int64(0)

# %%
df_cleaned.describe()
# Out:
#                   N             P             K   temperature      humidity  \
# count  31061.000000  31061.000000  31061.000000  31061.000000  31061.000000
# mean      65.358135     47.960133     54.150580     25.010339     73.661701
# std       38.677499     20.857843     41.028616      5.830112     16.059557
# min        0.000000      0.000000      0.000000     -9.770358      0.241239
# 25%       35.536146     36.898631     23.000000     21.806596     65.092249
# 50%       60.000000     44.000000     44.000000     25.833333     79.350140
# 75%       88.182468     60.000000     70.894401     28.648182     83.951944
# max      194.670114    150.000000    500.000000     47.861322    104.980970
#
#                  ph      rainfall
# count  31061.000000  31061.000000
# mean       6.205709    633.915258
# std        0.955917    601.272698
# min        0.005469      0.000000
# 25%        5.554824    107.086209
# 50%        6.218554    535.932899
# 75%        6.704871    965.094721
# max       13.989251   3322.060000

# %%
output_file = 'cleaned_data_output.csv'

# %%
df_cleaned.to_csv(output_file, index=False)
print(f"Successfully saved DataFrame to {output_file}")
# Out:
# Successfully saved DataFrame to cleaned_data_output.csv
